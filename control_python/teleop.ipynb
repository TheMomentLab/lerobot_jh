# %%
from lerobot.teleoperators.so_leader import SO101LeaderConfig, SO101Leader
from lerobot.robots.so_follower import SO101FollowerConfig, SO101Follower

robot_config = SO101FollowerConfig(
    port="/dev/follower_arm_1",
    id="my_so101_follower_1",
)
teleop_config = SO101LeaderConfig(
    port="/dev/leader_arm_1",
    id="my_so101_leader_1",
)
robot = SO101Follower(robot_config)
teleop_device = SO101Leader(teleop_config)

# %%
robot.connect()
teleop_device.connect()

# %%
while True:
    action = teleop_device.get_action()
    robot.send_action(action)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 while True:
#       2     action = teleop_device.get_action()
# ----> 3     robot.send_action(action)
#
# File ~/dev_ws/mt_lerobot/reference/lerobot/src/lerobot/utils/decorators.py:29, in check_if_not_connected.<locals>.wrapper(self, *args, **kwargs)
#      25 if not self.is_connected:
#      26     raise DeviceNotConnectedError(
#      27         f"{self.__class__.__name__} is not connected. Run `.connect()` first."
#      28     )
# ---> 29 return func(self, *args, **kwargs)
#
# File ~/dev_ws/mt_lerobot/reference/lerobot/src/lerobot/robots/so_follower/so_follower.py:234, in SOFollower.send_action(self, action)
#     231     goal_pos = ensure_safe_goal_position(goal_present_pos, self.config.max_relative_target)
#     233 # Send goal position to the arm
# --> 234 self.bus.sync_write("Goal_Position", goal_pos)
#     235 return {f"{motor}.pos": val for motor, val in goal_pos.items()}
#
# File ~/dev_ws/mt_lerobot/reference/lerobot/src/lerobot/utils/decorators.py:29, in check_if_not_connected.<locals>.wrapper(self, *args, **kwargs)
#      25 if not self.is_connected:
#      26     raise DeviceNotConnectedError(
#      27         f"{self.__class__.__name__} is not connected. Run `.connect()` first."
#      28     )
# ---> 29 return func(self, *args, **kwargs)
#
# File ~/dev_ws/mt_lerobot/reference/lerobot/src/lerobot/motors/motors_bus.py:1241, in SerialMotorsBus.sync_write(self, data_name, values, normalize, num_retry)
#    1238 ids_values = self._encode_sign(data_name, ids_values)
#    1240 err_msg = f"Failed to sync write '{data_name}' with {ids_values=} after {num_retry + 1} tries."
# -> 1241 self._sync_write(addr, length, ids_values, num_retry=num_retry, raise_on_error=True, err_msg=err_msg)
#
# File ~/dev_ws/mt_lerobot/reference/lerobot/src/lerobot/motors/motors_bus.py:1254, in SerialMotorsBus._sync_write(self, addr, length, ids_values, num_retry, raise_on_error, err_msg)
#    1252 self._setup_sync_writer(ids_values, addr, length)
#    1253 for n_try in range(1 + num_retry):
# -> 1254     comm = self.sync_writer.txPacket()
#    1255     if self._is_comm_success(comm):
#    1256         break
#
# File ~/miniforge3/envs/lerobot/lib/python3.10/site-packages/scservo_sdk/group_sync_write.py:73, in GroupSyncWrite.txPacket(self)
#      70 if self.is_param_changed is True or not self.param:
#      71     self.makeParam()
# ---> 73 return self.ph.syncWriteTxOnly(self.port, self.start_address, self.data_length, self.param,
#      74                                len(self.data_dict.keys()) * (1 + self.data_length))
#
# File ~/miniforge3/envs/lerobot/lib/python3.10/site-packages/scservo_sdk/protocol_packet_handler.py:462, in protocol_packet_handler.syncWriteTxOnly(self, port, start_address, data_length, param, param_length)
#     458 txpacket[PKT_PARAMETER0 + 1] = data_length
#     460 txpacket[PKT_PARAMETER0 + 2: PKT_PARAMETER0 + 2 + param_length] = param[0: param_length]
# --> 462 _, result, _ = self.txRxPacket(port, txpacket)
#     464 return result
#
# File ~/miniforge3/envs/lerobot/lib/python3.10/site-packages/scservo_sdk/protocol_packet_handler.py:177, in protocol_packet_handler.txRxPacket(self, port, txpacket)
#     173     #print "[RxPacket] %r" % rxpacket
#     175     return rxpacket, result
# --> 177 def txRxPacket(self, port, txpacket):
#     178     rxpacket = None
#     179     error = 0
#
# KeyboardInterrupt:

# %%
robot.disconnect()
teleop_device.disconnect()s
